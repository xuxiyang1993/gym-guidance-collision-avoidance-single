# %%
from baselines.common import plot_util as pu
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# Logging to C:\Users\xuxiyang\AppData\Local\Temp\openai-2019-01-21-18-15-03-468931

# %%
results = pu.load_results('openai-2019-01-21-12-22-27-333094/')
# Out:
# C:\Users\xuxiyang\Box Sync\Document\Python\AI\gym-guidance-collision-avoidance-single\baselines-master\baselines\bench\monitor.py:164: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %%
r = results[0]
plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
plt.title('raw data')
# Out:
# Text(0.5, 1.0, 'raw data')

# %%
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))
plt.ylabel('reward')
plt.title('smoothed data')
# Out:
# Text(0.5, 1.0, 'smoothed data')
